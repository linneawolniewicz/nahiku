# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lc = DipperDetector(time, flux)
s = DipperDetector.greedy_search()
anomalies = s.detect_anomaly()

anomalies = {
    'timestamp_idx': 'probability'
}
