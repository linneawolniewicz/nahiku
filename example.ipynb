# %%
import numpy as np
import matplotlib.pyplot as plt

from sys import path
path.append("./src")
from src.Nahiku import Nahiku
# Out:
# /mnt/lustre/koa/koastore/sadow_group/personal/linneamw/research/dipper_detection/nahiku/src/ExhaustiveSearch.py:347: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(self.x, pred_mean, lw=2, alpha=0.9, label="Predicted $\pm$ 1 $\sigma$")

# %%
x = np.arange(0, 100, 0.1)
y = np.sin(x) + np.random.normal(0, 0.1, size=x.shape)

nahiku = Nahiku(x, y)
nahiku.plot()
